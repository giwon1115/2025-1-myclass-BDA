# %% [markdown]
# <a href="https://colab.research.google.com/github/giwon1115/2025-1-myclass-BDA/blob/main/inclass/05w_A_mon_0407_easy_ch05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #p116 05-3 파생변수 생성

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({'var1':[4,3,8],'var2':[2,6,1]})
df#시험 가능성
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1=df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum']=df1.var1+df1.var2
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1.var_sum=df1.var1+df1.var2
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1.var_sum2=df1.var1+df1.var2
df1
# Out:
# <ipython-input-8-52ed6f7e3855>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.var_sum2=df1.var1+df1.var2
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1['var_mean']=(df1.var1+df1.var2)/2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df
# Out:
#    var1  var2
# 0     2     2
# 1     6     6
# 2     1     1

# %%
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2=df.copy()
df2
# Out:
#    var1  var2
# 0     2     2
# 1     6     6
# 2     1     1

# %%
df2.sum()
# Out:
# var1    9
# var2    9
# dtype: int64

# %%
df2.sum(axis=0)
# Out:
# var1    9
# var2    9
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# 0     4
# 1    12
# 2     2
# dtype: int64

# %%
df2['my_sum']=df2.sum(axis=1)
df2
# Out:
#    var1  var2  my_sum
# 0     2     2       8
# 1     6     6      24
# 2     1     1       4

# %%
df2.sum(axis=0)
# Out:
# var1       9
# var2       9
# my_sum    18
# dtype: int64

# %%
df2['my_sum']=df2.sum(axis='index')
df2
# Out:
#    var1  var2  my_sum
# 0     2     2     NaN
# 1     6     6     NaN
# 2     1     1     NaN

# %%
df2['my_sum']=df2.sum(axis='columns')
df2
# Out:
#    var1  var2  my_sum
# 0     2     2     4.0
# 1     6     6    12.0
# 2     1     1     2.0

# %%
df2[['var1','var2']]
# Out:
#    var1  var2
# 0     2     2
# 1     6     6
# 2     1     1

# %%
df2['var1']
# Out:
# 0    2
# 1    6
# 2    1
# Name: var1, dtype: int64

# %%
df2[['var1']]
# Out:
#    var1
# 0     2
# 1     6
# 2     1

# %%
df2['my_mean']=df2[['var1','var2']].mean(axis='columns')
df2# 새로운 열 var_mean <- var1과 var2의 평균,시험예상
# Out:
#    var1  var2  my_sum  my_mean
# 0     2     2     4.0      2.0
# 1     6     6    12.0      6.0
# 2     1     1     2.0      1.0

# %% [markdown]
# #mpg데이터

# %%
# !git clone https://github.com//ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 5.53 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
mpg=pd.read_csv('data/mpg.csv')
mpg.info()#mpg관련문제시험출제
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.sample(3)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 78          ford       explorer 4wd    4.0  1999    6  manual(m5)   4   15
# 205       toyota  toyota tacoma 4wd    4.0  2008    6  manual(m6)   4   15
# 176       toyota        4runner 4wd    3.4  1999    6  manual(m5)   4   15
#
#      hwy fl category  total
# 78    19  r      suv   17.0
# 205   18  r   pickup   16.5
# 176   17  r      suv   16.0

# %%
mpg['total']=(mpg.cty+mpg.hwy)/2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
mpg['mpg_mean']=mpg[['cty','hwy']].mean(axis=1)
mpg.sample(3)
# Out:
#     manufacturer               model  displ  year  cyl     trans drv  cty  \
# 122         jeep  grand cherokee 4wd    3.0  2008    6  auto(l5)   4   17
# 49         dodge   dakota pickup 4wd    3.7  2008    6  auto(l4)   4   14
# 178       toyota         4runner 4wd    4.7  2008    8  auto(l5)   4   14
#
#      hwy fl category  total  mpg_mean
# 122   22  d      suv   19.5      19.5
# 49    18  r   pickup   16.0      16.0
# 178   17  r      suv   15.5      15.5

# %%
sum(mpg['total'])/len(mpg) # total 합계를 행 수로 나누기
# Out:
# 20.14957264957265

# %%
mpg.total.mean()
# Out:
# np.float64(20.14957264957265)

# %%
mpg.shape
# Out:
# (234, 13)

# %%
len(mpg)
# Out:
# 234

# %%
sum(mpg['total'])/mpg.shape[0]#행 개수로 나눈다,시험?
# Out:
# 20.14957264957265

# %%
mpg.total.describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg.total.describe()['mean']
# Out:
# np.float64(20.14957264957265)

# %%
mpg.total.describe()[1]
# Out:
# <ipython-input-42-b4aef9eccf3a>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mpg.total.describe()[1]
# np.float64(20.14957264957265)

# %%
mpg.total.plot.hist(); #;=그래프 위 글자 삭제

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 54.5 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
mpg.total.plot(kind='hist',title='히스토그램');

# %%
import seaborn as sns
sns.histplot(mpg,x='total');

# %% [markdown]
# #np.where()

# %%
np.where(mpg.total>20,'pass','fail') # 20 이상이면 pass, 그렇지 않으면 fail 부여,시험?
# Out:
# array(['pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'fail', 'pass', 'pass', 'fail', 'fail',
#        'pass', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'pass',
#        'fail', 'pass', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fail',
#        'fail', 'pass', 'pass', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'pass', 'pass', 'pass', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'pass', 'pass', 'pass', 'pass', 'pass',
# ...

# %%
mpg['test']=np.where(mpg.total>20,'pass','fail')
mpg.sample(5)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 148       nissan             maxima    3.0  1999    6  manual(m5)   f   19
# 55         dodge  dakota pickup 4wd    5.2  1999    8  manual(m5)   4   11
# 208   volkswagen                gti    2.0  1999    4    auto(l4)   f   19
# 205       toyota  toyota tacoma 4wd    4.0  2008    6  manual(m6)   4   15
# 50         dodge  dakota pickup 4wd    3.9  1999    6    auto(l4)   4   13
#
#      hwy fl category  total  mpg_mean  test
# 148   25  r  midsize   22.0      22.0  pass
# 55    17  r   pickup   14.0      14.0  fail
# 208   26  r  compact   22.5      22.5  pass
# 205   18  r   pickup   16.5      16.5  fail
# 50    17  r   pickup   15.0      15.0  fail

# %%
mpg['test'].value_counts()
# Out:
# test
# pass    123
# fail    111
# Name: count, dtype: int64

# %%
mpg['test'].unique()
# Out:
# array(['pass', 'fail'], dtype=object)

# %%
count_test=mpg['test'].value_counts()

# %%
count_test
# Out:
# test
# pass    123
# fail    111
# Name: count, dtype: int64

# %%
count_test.plot.bar();# 연비 합격 빈도 막대 그래프 만들기

# %%
count_test.plot.bar(rot=0);# 축 이름 수평으로 만들기

# %%
sns.countplot(mpg,x='test',hue='test')
# Out:
# <Axes: xlabel='test', ylabel='count'>

# %%
sns.countplot(mpg,x='test',hue='test',stat='percent') # 시험 예상
# Out:
# <Axes: xlabel='test', ylabel='percent'>

# %%
sns.countplot(data=mpg, x="test", hue="cyl", stat= "percent"); # 시험 예상

# %%
sns.countplot(data=mpg, x="test", hue="category", stat= "percent"); # 시험 예상

# %%
mpg['grade']=np.where(mpg.total>=30,'A',np.where(mpg.total>=20,'B','C'))# total 기준으로 A, B, C 등급 부여
mpg.sample(5)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 197       toyota              corolla    1.8  2008    4    auto(l4)   f   26
# 205       toyota    toyota tacoma 4wd    4.0  2008    6  manual(m6)   4   15
# 76          ford       expedition 2wd    5.4  2008    8    auto(l6)   r   12
# 231   volkswagen               passat    2.8  1999    6    auto(l5)   f   16
# 70         dodge  ram 1500 pickup 4wd    5.2  1999    8    auto(l4)   4   11
#
#      hwy fl category  total  mpg_mean  test grade
# 197   35  r  compact   30.5      30.5  pass     A
# 205   18  r   pickup   16.5      16.5  fail     C
# 76    18  r      suv   15.0      15.0  fail     C
# 231   26  p  midsize   21.0      21.0  pass     B
# 70    15  r   pickup   13.0      13.0  fail     C

# %%
count_grade=mpg['grade'].value_counts()
count_grade
# Out:
# grade
# B    118
# C    106
# A     10
# Name: count, dtype: int64

# %%
count_grade.plot.bar(rot = 0) ;

# %%
count_grade = mpg['grade'].value_counts().sort_index()  # 등급 빈도표 만들기
count_grade
# Out:
# grade
# A     10
# B    118
# C    106
# Name: count, dtype: int64

# %%
count_grade.plot.bar(rot = 0) ;

# %%
sns.countplot(mpg,x='grade',hue='grade',stat='percent')
# Out:
# <Axes: xlabel='grade', ylabel='percent'>

# %%
sns.countplot(mpg,x='grade',hue='grade',stat='percent')
# Out:
# <Axes: xlabel='grade', ylabel='percent'>

# %%
mpg.grade.value_counts()
# Out:
# grade
# B    118
# C    106
# A     10
# Name: count, dtype: int64

# %%
mpg['grade'].value_counts().sort_index().index
# Out:
# Index(['A', 'B', 'C'], dtype='object', name='grade')

# %%
sns.countplot(mpg,x='grade',hue='grade',order=mpg.grade.value_counts().sort_index().index)
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
sns.countplot(mpg, x="grade", hue="grade", stat='percent', order=["A", "B", "C"]);

# %%
mpg.grade.unique()
# Out:
# array(['B', 'C', 'A'], dtype=object)

# %%
np.sort(mpg.grade.unique())
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
sns.countplot(mpg, x="grade", hue="grade", order=np.sort(mpg.grade.unique()));

# %% [markdown]
# #메서드 체이닝

# %%
s=mpg.grade
s=s.value_counts()
s=s.sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
s=mpg.grade.value_counts().sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
mpg.grade.value_counts().sort_index()
# Out:
# grade
# A     10
# B    118
# C    106
# Name: count, dtype: int64

# %%
mpg['grade']=np.where(mpg.total>=30,'A',
                      np.where(mpg.total>=25,'B',
                      np.where(mpg.total>=20,'C','D')))
mpg.sample(5)
# Out:
#         company         model  displ  year  cyl       trans drv  cty  hwy fl  \
# 191      toyota  camry solara    3.0  1999    6  manual(m5)   f   18   26  r
# 232  volkswagen        passat    2.8  1999    6  manual(m5)   f   18   26  p
# 4          audi            a4    2.8  1999    6    auto(l5)   f   16   26  p
# 167      subaru   impreza awd    2.5  1999    4  manual(m5)   4   19   26  r
# 192      toyota  camry solara    3.3  2008    6    auto(s5)   f   18   27  r
#
#        category  total  test grade
# 191     compact   22.0  pass     C
# 232     midsize   22.0  pass     C
# 4       compact   21.0  pass     C
# 167  subcompact   22.5  pass     C
# 192     compact   22.5  pass     C

# %%
mpg['size']=np.where((mpg.category=='compact')|(mpg.category=='subcontact')|(mpg.category=='2seater'),'small','large')

# %%
mpg['size'].value_counts()
# Out:
# size
# large    182
# small     52
# Name: count, dtype: int64

# %%
mpg.sample(3)
# Out:
#      company                   model  displ  year  cyl       trans drv  cty  \
# 117  hyundai                 tiburon    2.0  2008    4  manual(m5)   f   20
# 199   toyota  land cruiser wagon 4wd    5.7  2008    8    auto(s6)   4   13
# 107    honda                   civic    2.0  2008    4  manual(m6)   f   21
#
#      hwy fl    category  total  test
# 117   28  r  subcompact   24.0  pass
# 199   18  r         suv   15.5  fail
# 107   29  p  subcompact   25.0  pass

# %%
mpg.size
# Out:
# 3510

# %%
mpg.shape
# Out:
# (234, 15)

# %%
mpg.shape[0]*mpg.shape[1]
# Out:
# 3510

# %%
mpg['size']=np.where((mpg.category.isin(['contact','subcontact','2seater'])),'small','large')#시험가능성
mpg['size'].value_counts()
# Out:
# size
# large    229
# small      5
# Name: count, dtype: int64

# %%
# 2. 데이터 불러오기
mpg=pd.read_csv('data/mpg.csv')
# 3. 데이터 파악하기
mpg.shape
mpg.head() # 데이터 앞부분
mpg.tail()      # 데이터 뒷부분
mpg.info()    # 속성
mpg.describe()

# 4. 변수명 바꾸기
mpg=mpg.rename(columns={'manufacturer':'company'})
# 5. 파생변수 만들기
mpg['total']=(mpg['cty']+mpg['hwy'])/2 # 변수 조합
mpg['test']=np.where(mpg['total']>=20,'pass','fail')
# 6. 빈도 확인하기
count_test=mpg['test'].value_counts()
count_test.plot.bar(rot=0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB
# <Axes: xlabel='test'>

# %% [markdown]
# #단원06

# %%
exam=pd.read_csv('data/exam.csv')
exam.sample(5)
# Out:
#    id  nclass  math  english  science
# 5   6       2    50       89       98
# 1   2       1    60       97       60
# 0   1       1    50       98       50
# 8   9       3    20       98       15
# 9  10       3    50       98       45

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 932.0 bytes

# %%
exam.sample(frac=.2)
# Out:
#     id  nclass  math  english  science
# 13  14       4    48       87       12
# 19  20       5    78       83       58
# 17  18       5    80       78       90
# 16  17       5    65       68       98

# %%
exam.query('nclass==2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('nclass != 1')
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
(exam['nclass'] == 2)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: nclass, dtype: bool

# %%
exam.query('nclass == 2')
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('math>50')
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('english>=80')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65
# 19  20       5    78       83       58

# %%
exam.query('nclass==1&math>=50')# 1반이면서 수학 점수가 50 점 이상인 경우
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam[exam.nclass==1 & exam.math>=50]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-9575ed97cd5a> in <cell line: 0>()
# ----> 1 exam[exam.nclass==1 & exam.math>=50]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
exam[(exam.nclass==1) & (exam.math>=50)]# 괄호를 반드시 사용
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.query('english<90 | science<50')
# Out:
#     id  nclass  math  english  science
# 2    3       1    45       86       78
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass == 1 | nclass == 3 | nclass == 5')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
a=[1,3,5]
1 in a
# Out:
# True

# %%
4 in a
# Out:
# False

# %%
exam.query('nclass in [1,3,5]')# 시험 예상
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass.isin ([1,3,5])')# 시험 예상
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[exam.nclass.isin ([1,3,5])]# 시험 예상
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
nclass1=exam.query("nclass==1")
nclass1
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
nclass2=exam.query('nclass==2')
nclass2
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
nclass1.math.mean()
# Out:
# np.float64(46.25)

# %%
nclass2.english.mean()
# Out:
# np.float64(84.25)

# %%
df=pd.DataFrame({'sex':['M','F','F','M'],'country' : ['Korea', 'China', 'Japan', 'USA']})
df
# Out:
#   sex country
# 0   M   Korea
# 1   F   China
# 2   F   Japan
# 3   M     USA

# %%
df.query('sex == "M" & country == "Korea"')
# Out:
#   sex country
# 0   M   Korea

# %%
df.query("sex == 'M' & country == 'Korea'")
# Out:
#   sex country
# 0   M   Korea

# %%
var=3
exam.query("nclass==@var")
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %%
var=3
exam.query(f'nclass=={var}')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %%
df = pd.DataFrame({'num_legs': [2, 4], 'num_wings': [2, 0]},
                  index=['falcon', 'dog'])
df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0

# %%
df.isin([0, 4])
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog         True       True

# %%
~df.isin([0, 4])
# Out:
#         num_legs  num_wings
# falcon      True       True
# dog        False      False

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.columns
# Out:
# Index(['id', 'nclass', 'math', 'english', 'science'], dtype='object')

# %%
exam.columns[1]
# Out:
# 'nclass'

# %%
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam[exam.columns[2]]
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam.math
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam.columns[1:4]
# Out:
# Index(['nclass', 'math', 'english'], dtype='object')

# %%
exam[exam.columns[1:4]]
# Out:
#     nclass  math  english
# 0        1    50       98
# 1        1    60       97
# 2        1    45       86
# 3        1    30       98
# 4        2    25       80
# 5        2    50       89
# 6        2    80       90
# 7        2    90       78
# 8        3    20       98
# 9        3    50       98
# 10       3    65       65
# 11       3    45       85
# 12       4    46       98
# 13       4    48       87
# 14       4    75       56
# 15       4    58       98
# 16       5    65       68
# 17       5    80       78
# 18       5    89       68
# 19       5    78       83

# %%
exam[['nclass', 'math', 'english']]
# Out:
#     nclass  math  english
# 0        1    50       98
# 1        1    60       97
# 2        1    45       86
# 3        1    30       98
# 4        2    25       80
# 5        2    50       89
# 6        2    80       90
# 7        2    90       78
# 8        3    20       98
# 9        3    50       98
# 10       3    65       65
# 11       3    45       85
# 12       4    46       98
# 13       4    48       87
# 14       4    75       56
# 15       4    58       98
# 16       5    65       68
# 17       5    80       78
# 18       5    89       68
# 19       5    78       83

# %%
exam[exam.columns[1:4]].head()
# Out:
#    nclass  math  english
# 0       1    50       98
# 1       1    60       97
# 2       1    45       86
# 3       1    30       98
# 4       2    25       80

# %%
exam[['nclass', 'math', 'english']].head()
# Out:
#    nclass  math  english
# 0       1    50       98
# 1       1    60       97
# 2       1    45       86
# 3       1    30       98
# 4       2    25       80

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(columns=['math','english'])#math,english 제거한것을 반환
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam.drop(columns='math')
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
exam.drop(columns=['math'])
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(2)#2행삭제
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(index=2)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(index=[2,4,6])#2,4,6행 삭제
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=[2,4,6])
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=[2,4,6],axis=0)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=['math','english'],axis=1)#열 삭제
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass==1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass==1')["math"]
# Out:
# 0    50
# 1    60
# 2    45
# 3    30
# Name: math, dtype: int64

# %%
exam.query('nclass==1').math
# Out:
# 0    50
# 1    60
# 2    45
# 3    30
# Name: math, dtype: int64

# %%
exam.query('nclass==1')[["math"]]
# Out:
#    math
# 0    50
# 1    60
# 2    45
# 3    30

# %%
exam.query('nclass==1')["math"].to_frame()
# Out:
#    math
# 0    50
# 1    60
# 2    45
# 3    30

# %%
exam.query('nclass==1')[["math","science"]]
# Out:
#    math  science
# 0    50       50
# 1    60       60
# 2    45       78
# 3    30       58

# %%
exam.query('math>=50')[["id","math"]]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam[exam.math>=50][["id","math"]]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam[exam.math>=50][["id","math"]].head()#앞에것만
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
exam[exam.math>=50]\
  [["id","math"]]\
  .head()

# %% [markdown]
# #정렬

# %%
exam.sort_values('math')#수학성적 오름차순
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 0    1       1    50       98       50
# 5    6       2    50       89       98
# 9   10       3    50       98       45
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
exam.sort_values('math',ascending=False)#수학성적 내림차순
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 0    1       1    50       98       50
# 5    6       2    50       89       98
# 9   10       3    50       98       45
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
exam.sort_values('math',ascending=False).head()
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58

# %%
exam.sort_values(['nclass','math'],ascending=[True,False]).head(10)#nclass->True,math->Flase
#1,2,3반 모두 수학이 높은것부터 나옴
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45

# %%
exam.sort_index(ascending=False).head()
# Out:
#     id  nclass  math  english  science
# 19  20       5    78       83       58
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 16  17       5    65       68       98
# 15  16       4    58       98       65

# %%
exam.sort_index(axis=1,ascending=False).head()#행 내림차순
# Out:
#    science  nclass  math  id  english
# 0       50       1    50   1       98
# 1       60       1    60   2       97
# 2       78       1    45   3       86
# 3       58       1    30   4       98
# 4       65       2    25   5       80

# %%
exam.sort_index(axis=1).head()
# Out:
#    english  id  math  nclass  science
# 0       98   1    50       1       50
# 1       97   2    60       1       60
# 2       86   3    45       1       78
# 3       98   4    30       1       58
# 4       80   5    25       2       65

# %% [markdown]
# #종료
