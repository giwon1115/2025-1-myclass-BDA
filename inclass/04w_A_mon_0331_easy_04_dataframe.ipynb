# %% [markdown]
# <a href="https://colab.research.google.com/github/giwon1115/2025-1-myclass-BDA/blob/main/inclass/04w_A_mon_0331_easy_04_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #04주 쉽게 배우는 데이터분석 단원04

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
ttn=sns.load_dataset('titanic')
ttn.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ttn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ### 타이타닉 열(변수) 설명
# - survived : 0 = 사망, 1 = 생존
# - pclass : 1 = 1등석, 2 = 2등석, 3 = 3등석
# - sex : male = 남성, female = 여성
# - age : 나이
# - sibsp : 타이타닉 호에 동승한 자매 / 배우자의 수
# - parch : 타이타닉 호에 동승한 부모 / 자식의 수
# - fare : 티켓 요금
# - embarked : 탑승지, C = 셰르부르, Q = 퀸즈타운, S = 사우샘프턴
# - class : First = 1등석, Second = 2등석, Third = 3등석
# - who : 남/여/아이, 'man', 'woman', 'child'
# - adult_male : 남자 어른, True/False
# - deck : 방 위치, 'A', 'B', 'C', 'D', 'E', 'F', 'G', NaN
# - embark_town : 탑승지
# - alive : 생존, yes/no
# - alone : 1인 탑승, True/False

# %%
# %config InlineBackend.figure_format = 'retina'#그래프 선명하게

# %%
sns.countplot(ttn,x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(ttn,x="class")
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(ttn,x="deck")
# Out:
# <Axes: xlabel='deck', ylabel='count'>

# %%
sns.countplot(ttn,x="deck",hue="deck")
# Out:
# <Axes: xlabel='deck', ylabel='count'>

# %%
sns.countplot(ttn,x="class",hue="alive") #class를 alive에 따라 나눔
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(ttn,x="who",hue="alive",stat="percent")#남 여 아이 산/죽은사람 퍼센트
# Out:
# <Axes: xlabel='who', ylabel='percent'>

# %% [markdown]
# #열 검사

# %%
ttn['pclass'] #시리즈
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int64

# %%
type(ttn["pclass"])
# Out:
# pandas.core.series.Series

# %%
ttn[["pclass"]]#데이터프레임
# Out:
#      pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
ttn[["pclass", "alive"]]
# Out:
#      pclass alive
# 0         3    no
# 1         1   yes
# 2         3   yes
# 3         1   yes
# 4         3    no
# ..      ...   ...
# 886       2    no
# 887       1   yes
# 888       3    no
# 889       1   yes
# 890       3    no
#
# [891 rows x 2 columns]

# %%
ttn.pclass.values
# Out:
# array([3, 1, 3, 1, 3, 3, 1, 3, 3, 2, 3, 1, 3, 3, 3, 2, 3, 2, 3, 3, 2, 2,
#        3, 1, 3, 3, 3, 1, 3, 3, 1, 1, 3, 2, 1, 1, 3, 3, 3, 3, 3, 2, 3, 2,
#        3, 3, 3, 3, 3, 3, 3, 3, 1, 2, 1, 1, 2, 3, 2, 3, 3, 1, 1, 3, 1, 3,
#        2, 3, 3, 3, 2, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 2, 3, 3, 3,
#        1, 3, 3, 3, 1, 3, 3, 3, 1, 1, 2, 2, 3, 3, 1, 3, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 3, 3, 3, 3, 2, 1, 3, 2, 3, 2, 2, 1, 3, 3, 3, 3, 3, 3, 3,
#        3, 2, 2, 2, 1, 1, 3, 1, 3, 3, 3, 3, 2, 2, 3, 3, 2, 2, 2, 1, 3, 3,
#        3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 1, 3, 1, 3, 1, 3, 3, 3, 1, 3,
#        3, 1, 2, 3, 3, 2, 3, 2, 3, 1, 3, 1, 3, 3, 2, 2, 3, 2, 1, 1, 3, 3,
#        3, 2, 3, 3, 3, 3, 3, 3, 3, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 1, 2,
#        3, 2, 3, 3, 1, 3, 2, 3, 2, 3, 1, 3, 2, 3, 2, 3, 2, 2, 2, 2, 3, 3,
#        2, 3, 3, 1, 3, 2, 1, 2, 3, 3, 1, 3, 3, 3, 1, 1, 1, 2, 3, 3, 1, 1,
#        3, 2, 3, 3, 1, 1, 1, 3, 2, 1, 3, 1, 3, 2, 3, 3, 3, 3, 3, 3, 1, 3,
# ...

# %%
ttn.pclass.unique()
# Out:
# array([3, 1, 2])

# %%
ttn.pclass.nunique()
# Out:
# 3

# %%
ttn.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
ttn.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-f070d0b14e87> in <cell line: 0>()
# ----> 1 ttn.unique()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
ttn.pclass.value_counts()
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
ttn.pclass.value_counts().sort_index()
# Out:
# pclass
# 1    216
# 2    184
# 3    491
# Name: count, dtype: int64

# %%
ttn.pclass.value_counts().sort_values()
# Out:
# pclass
# 2    184
# 1    216
# 3    491
# Name: count, dtype: int64

# %% [markdown]
# #열 별 그룹화

# %%
ttn.groupby('sex').count()
# Out:
#         survived  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex
# female       314     314  261    314    314   314       312    314  314
# male         577     577  453    577    577   577       577    577  577
#
#         adult_male  deck  embark_town  alive  alone
# sex
# female         314    97          312    314    314
# male           577   106          577    577    577

# %%
ttn.groupby('sex')

# %%
ttn.groupby('who').count()
# Out:
#        survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# who
# child        83      83   83   83     83     83    83        83     83
# man         537     537  537  413    537    537   537       537    537
# woman       271     271  271  218    271    271   271       269    271
#
#        adult_male  deck  embark_town  alive  alone
# who
# child          83    13           83     83     83
# man           537    99          537    537    537
# woman         271    91          269    271    271

# %%
ttn.groupby('embark_town').count()
# Out:
#              survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# embark_town
# Cherbourg         168     168  168  130    168    168   168       168    168
# Queenstown         77      77   77   28     77     77    77        77     77
# Southampton       644     644  644  554    644    644   644       644    644
#
#              who  adult_male  deck  alive  alone
# embark_town
# Cherbourg    168         168    69    168    168
# Queenstown    77          77     4     77     77
# Southampton  644         644   128    644    644

# %%
ttn.groupby("pclass")

# %%
ttn.groupby("pclass")["fare"]

# %%
ttn.groupby("pclass")["fare"].mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
ttn.groupby("embark_town")["fare"].mean()
# Out:
# embark_town
# Cherbourg      59.954144
# Queenstown     13.276030
# Southampton    27.079812
# Name: fare, dtype: float64

# %% [markdown]
# #막대그래프

# %%
sns.barplot(data=ttn,x="sex",y="survived")#남자 20퍼 생존 여자 70퍼 생존
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(data=ttn,x="sex",y="survived",hue="sex")
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(data=ttn,x="pclass",y="survived",hue="sex")
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %%
sns.barplot(data=ttn,x="class",y="fare",hue="sex")
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot(data=ttn,x="deck",y="fare",hue="class")
# Out:
# <Axes: xlabel='deck', ylabel='fare'>

# %%
sns.barplot(data=ttn,x="deck",y="survived",hue="class")#deck=방 위치
# Out:
# <Axes: xlabel='deck', ylabel='survived'>

# %% [markdown]
# #단원04

# %%
import pandas as pd

df = pd.DataFrame({"name": ["김지훈", "이유진", "박종현", "김민지"],
                   "english": [90, 80, 60, 70],
                   "math": [50, 60, 100, 20]})
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박종현       60   100
# 3  김민지       70    20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     4 non-null      object
#  1   english  4 non-null      int64
#  2   math     4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#          english        math
# count   4.000000    4.000000
# mean   75.000000   57.500000
# std    12.909944   33.040379
# min    60.000000   20.000000
# 25%    67.500000   42.500000
# 50%    75.000000   55.000000
# 75%    82.500000   70.000000
# max    90.000000  100.000000

# %%
df.describe(include="all")
# Out:
#        name    english        math
# count     4   4.000000    4.000000
# unique    4        NaN         NaN
# top     김지훈        NaN         NaN
# freq      1        NaN         NaN
# mean    NaN  75.000000   57.500000
# std     NaN  12.909944   33.040379
# min     NaN  60.000000   20.000000
# 25%     NaN  67.500000   42.500000
# 50%     NaN  75.000000   55.000000
# 75%     NaN  82.500000   70.000000
# max     NaN  90.000000  100.000000

# %%
df['math']
# Out:
# 0     50
# 1     60
# 2    100
# 3     20
# Name: math, dtype: int64

# %%
sum(df['math'])
# Out:
# 230

# %%
sum(df['english'])
# Out:
# 300

# %%
df['math'].sum()
# Out:
# np.int64(230)

# %%
df['english'].sum()
# Out:
# np.int64(300)

# %%
mean(df['math'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-4947211e36f9> in <cell line: 0>()
# ----> 1 mean(df['math'])
#
# NameError: name 'mean' is not defined

# %%
df['english'].mean()
# Out:
# np.float64(75.0)

# %%
sum(df["english"]) / len(df)#영어열 평균
# Out:
# 75.0

# %%
sum(df["math"]) / len(df)#수학 열 평균
# Out:
# 57.5

# %%
sum(df['english'])/df.shape[0]
# Out:
# 75.0

# %%
df.english.mean()
# Out:
# np.float64(75.0)

# %%
df.sum()
# Out:
# name       김지훈이유진박종현김민지
# english             300
# math                230
# dtype: object

# %%
df.sum(axis=0)
# Out:
# name       김지훈이유진박종현김민지
# english             300
# math                230
# dtype: object

# %%
df.sum(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-f6cc363c055e> in <cell line: 0>()
# ----> 1 df.sum(axis=1)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11668         **kwargs,
#   11669     ):
# > 11670         result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671         return result.__finalize__(self, method="sum")
#   11672
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12504         **kwargs,
#   12505     ):
# > 12506         return self._min_count_stat_function(
#   12507             "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12508         )
#
# ...

# %%
df.sum(axis=1,numeric_only=True)#가로 합
# Out:
# 0    140
# 1    140
# 2    160
# 3     90
# dtype: int64

# %%
df.sum(axis='columns',numeric_only=True)
# Out:
# 0    140
# 1    140
# 2    160
# 3     90
# dtype: int64

# %% [markdown]
# #외부 데이터 활용

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 5.39 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
exam=pd.read_excel('data/excel_exam.xlsx')
exam#sheet1(자동)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 932.0 bytes

# %%
exam.describe()
# Out:
#              id     nclass       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %%
exam.english.mean()
# Out:
# np.float64(84.9)

# %%
exam_novar=pd.read_excel('data/excel_exam_novar.xlsx')
exam_novar
# Out:
#    1  1.1  50  98  50.1
# 0  2    1  60  97    60
# 1  3    2  25  80    65
# 2  4    2  50  89    98
# 3  5    3  20  98    15
# 4  6    3  50  98    45
# 5  7    4  46  98    65
# 6  8    4  48  87    12

# %%
exam_novar=pd.read_excel('data/excel_exam_novar.xlsx',header=None)
exam_novar#첫 행 데이터가 안으로 들어옴
# Out:
#    0  1   2   3   4
# 0  1  1  50  98  50
# 1  2  1  60  97  60
# 2  3  2  25  80  65
# 3  4  2  50  89  98
# 4  5  3  20  98  15
# 5  6  3  50  98  45
# 6  7  4  46  98  65
# 7  8  4  48  87  12

# %%
exam=pd.read_excel('data/excel_exam.xlsx',sheet_name='Sheet2')
exam.tail()#sheet2내용
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83      100

# %%
exam=pd.read_excel('data/excel_exam.xlsx',sheet_name=0)
exam.tail()#sheet1(번호로 지정)
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df=pd.read_csv('data/exam.csv')
df.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %%
df.to_csv('output.csv')

# %%
df.to_csv('output.csv',index=False)

# %% [markdown]
# #혼자서 해보기

# %%
mydf=pd.DataFrame({'제품':['사과','딸기','수박'],
                   '가격':[1800,1500,3000],
                   '판매량':[24,38,13]})
mydf
# Out:
#    제품    가격  판매량
# 0  사과  1800   24
# 1  딸기  1500   38
# 2  수박  3000   13

# %%
mydf.sum(axis=0,numeric_only=True)
# Out:
# 가격     6300
# 판매량      75
# dtype: int64

# %%
mydf.mean(axis=0,numeric_only=True)
# Out:
# 가격     2100.0
# 판매량      25.0
# dtype: float64

# %%
mydf.sum(axis=1,numeric_only=True)
# Out:
# 0    1824
# 1    1538
# 2    3013
# dtype: int64

# %%
mydf.mean(axis=1,numeric_only=True)
# Out:
# 0     912.0
# 1     769.0
# 2    1506.5
# dtype: float64

# %% [markdown]
# #정리하기

# %%
df = pd.DataFrame({'name'    : ['김지훈', '이유진', '박동현', '김민지'],
                   'english' : [90, 80, 60, 70],
                   'math'    : [50, 60, 100, 20]})
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df_exam = pd.read_excel('data/excel_exam.xlsx')

# %%
df_csv_exam = pd.read_csv('data/exam.csv')

# %%
df_midterm = pd.DataFrame({'english' : [90, 80, 60, 70],
                           'math'    : [50, 60, 100, 20],
                           'nclass'  : [1, 1, 2, 2]})
df_midterm.to_csv('data/output_newdata2.csv')
df_midterm.to_csv('data/output_newdata3.csv', index = False)

# %% [markdown]
# #단원05

# %% [markdown]
# #mpg데이터 파악하기

# %%
import pandas as pd
mpg=pd.read_csv('data/mpg.csv')
mpg.head(7)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
# 5         audi    a4    2.8  1999    6  manual(m5)   f   18   26  p  compact
# 6         audi    a4    3.1  2008    6    auto(av)   f   18   27  p  compact

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.sample(5)#임의로 5개의 행
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 99         honda                civic    1.6  1999    4  manual(m5)   f   28
# 66         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4   13
# 21     chevrolet   c1500 suburban 2wd    5.7  1999    8    auto(l4)   r   13
# 55         dodge    dakota pickup 4wd    5.2  1999    8  manual(m5)   4   11
# 180       toyota                camry    2.2  1999    4    auto(l4)   f   21
#
#      hwy fl    category
# 99    33  r  subcompact
# 66    17  r      pickup
# 21    17  r         suv
# 55    17  r      pickup
# 180   27  r     midsize

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
mpg.describe(include='all')
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl category
# count        234  234  234.000000  234.000000  234      234
# ...

# %%
mpg[["category"]]
# Out:
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 1 columns]

# %%
mpg[["category"]].describe()
# Out:
#        category
# count       234
# unique        7
# top         suv
# freq         62

# %%
mpg[["manufacturer", "model", "trans", "drv", "fl", "category"]].describe()
# Out:
#        manufacturer        model     trans  drv   fl category
# count           234          234       234  234  234      234
# unique           15           38        10    3    5        7
# top           dodge  caravan 2wd  auto(l4)    f    r      suv
# freq             37           11        83  106  168       62

# %%
mpg.fl.unique()#regular,premium,ethanol,disel,methanol 그닥 안중요
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg["fl"].unique()
# Out:
# array(['p', 'r', 'e', 'd', 'c'], dtype=object)

# %%
mpg.value_counts()
# Out:
# manufacturer  model                displ  year  cyl  trans       drv  cty  hwy  fl  category
# chevrolet     c1500 suburban 2wd   5.3    2008  8    auto(l4)    r    14   20   r   suv           2
# ford          explorer 4wd         4.0    1999  6    auto(l5)    4    14   17   r   suv           2
# honda         civic                1.6    1999  4    auto(l4)    f    24   32   r   subcompact    2
# dodge         ram 1500 pickup 4wd  4.7    2008  8    manual(m6)  4    12   16   r   pickup        2
#                                                      auto(l5)    4    13   17   r   pickup        2
#                                                                                                  ..
# volkswagen    passat               2.0    2008  4    auto(s6)    f    19   28   p   midsize       1
#                                                      manual(m6)  f    21   29   p   midsize       1
# ...

# %%
mpg.value_counts().sort_values(ascending=False)
# Out:
# manufacturer  model                displ  year  cyl  trans       drv  cty  hwy  fl  category
# chevrolet     c1500 suburban 2wd   5.3    2008  8    auto(l4)    r    14   20   r   suv           2
# ford          explorer 4wd         4.0    1999  6    auto(l5)    4    14   17   r   suv           2
# honda         civic                1.6    1999  4    auto(l4)    f    24   32   r   subcompact    2
# dodge         ram 1500 pickup 4wd  4.7    2008  8    manual(m6)  4    12   16   r   pickup        2
#                                                      auto(l5)    4    13   17   r   pickup        2
#                                                                                                  ..
# volkswagen    passat               2.0    2008  4    auto(s6)    f    19   28   p   midsize       1
#                                                      manual(m6)  f    21   29   p   midsize       1
# ...

# %%
mpg[["category"]].value_counts()
# Out:
# category
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: count, dtype: int64

# %%
mpg[['fl',"category"]].value_counts()
# Out:
# fl  category
# r   suv           48
#     pickup        30
#     subcompact    29
#     midsize       26
#     compact       25
# p   compact       21
#     midsize       15
# r   minivan       10
# p   suv            8
#     2seater        5
# e   suv            4
#     pickup         3
# p   subcompact     3
# d   subcompact     2
#     suv            2
# c   subcompact     1
# d   compact        1
# e   minivan        1
# Name: count, dtype: int64

# %%
mpg[['fl',"category"]].value_counts().to_frame()#데이터프레임으로
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
mpg[['fl',"category"]].value_counts().to_frame().index
# Out:
# MultiIndex([('r',        'suv'),
#             ('r',     'pickup'),
#             ('r', 'subcompact'),
#             ('r',    'midsize'),
#             ('r',    'compact'),
#             ('p',    'compact'),
#             ('p',    'midsize'),
#             ('r',    'minivan'),
#             ('p',        'suv'),
#             ('p',    '2seater'),
#             ('e',        'suv'),
#             ('e',     'pickup'),
#             ('p', 'subcompact'),
#             ('d', 'subcompact'),
#             ('d',        'suv'),
#             ('c', 'subcompact'),
#             ('d',    'compact'),
#             ('e',    'minivan')],
#            names=['fl', 'category'])

# %% [markdown]
# #함수와 메서드 차이

# %%
sum([4,7,8])#함수
# Out:
# 19

# %%
df=pd.DataFrame({'x':[10,20,30]})#패키지 함수
df.head()#객체의 메소드,소속된 객체나 클래스가 있어야 함
# Out:
#     x
# 0  10
# 1  20
# 2  30

# %% [markdown]
# #변수명 바꾸기

# %%
df_raw=pd.DataFrame({'var1':[1,2,1],
                     'var2':[2,3,2],
                     'var3':[10,20,30]})
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new=df_raw.copy()
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(columns={'var2':'v2'})
df_new
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_new.rename(columns={'var2':'v2'},inplace=True)#원래의 데이터프레임이 직접 수정됨
df_new
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_new.rename(index={0:'x',1:'y',2:'z'},inplace=True)
df_new
# Out:
#    var1  v2  var3
# x     1   2    10
# y     2   3    20
# z     1   2    30

# %%
df=pd.DataFrame({"A":[1,2,3],"B":[4,5,6]})
df.rename(columns={"A": "aa", "B": "bb"},inplace=True)
df
# Out:
#    aa  bb
# 0   1   4
# 1   2   5
# 2   3   6

# %% [markdown]
# #종료
